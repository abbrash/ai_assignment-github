# %% [markdown]
# # Artificial Intelligence and Expert Systems
# ## Assignment 03
# ### Experiment II:
# ### Recurrent Neural Network (RNN)

# %% [markdown]
# ### I. Explain the basic architecture of an RNN and how it is different from a feedforward neural network. What are the advantages and disadvantages of using an RNN?

# %% [markdown]
# The basic architecture of a Recurrent Neural Network (RNN) consists of recurrent connections that allow information to be passed from previous steps to the current step, making it suitable for processing sequential data. The key difference between an RNN and a feedforward neural network (FNN) lies in their treatment of sequential data.
#
# In a typical RNN, the input at each time step is not only influenced by the current input but also by the hidden state from the previous time step. The hidden state acts as a memory that captures the information from past steps, enabling the network to maintain context and make predictions based on the entire sequence.
#
# The key advantages of using an RNN are:
#
# 1. Sequential Processing:
#
#     RNNs are designed to process sequential data such as time series, speech, and natural language. They can capture temporal dependencies and handle inputs of varying lengths, making them suitable for tasks where the order of the input matters.
#
# 2. Variable-Length Input:
#
#     RNNs can handle inputs of different lengths within the same model architecture. This flexibility is particularly useful for tasks where the length of the sequence may vary, such as text classification or speech recognition.
#
# 3. Memory and Context:
#
#     The recurrent connections in an RNN allow the network to maintain memory and context over time. This capability is beneficial for tasks requiring a historical context, such as language modeling or sentiment analysis.
#
# Despite their advantages, RNNs also have some limitations and disadvantages:
#
# 1. Vanishing/Exploding Gradient:
#
#     RNNs can suffer from the vanishing or exploding gradient problem, where the gradient signal diminishes or amplifies exponentially as it propagates back through time. This issue can make training RNNs challenging and lead to difficulties in capturing long-term dependencies.
#
# 2. Computational Complexity:
#
#     RNNs can be computationally expensive, especially when dealing with long sequences. The sequential nature of RNNs limits parallelization, which can result in slower training and inference times compared to feedforward networks.
#
# 3. Short-Term Memory:
#
#     Traditional RNNs have limitations in capturing long-term dependencies due to the vanishing gradient problem. Although solutions like Long Short-Term Memory (LSTM) and Gated Recurrent Unit (GRU) have been introduced to mitigate this issue, they can be more complex to train and require more parameters.
#
# 4. Limited Context:
#
#     RNNs primarily focus on the context from previous time steps and may struggle with capturing dependencies that are distant in the sequence. Tasks that require a broader context, such as document understanding, might benefit from other architectures like Transformers.

# %% [markdown]
# ### II. What is the problem of vanishing and exploding gradients in RNNs? How can this problem be mitigated?

# %% [markdown]
# The vanishing gradient problem is essentially a situation in which a deep multilayer feed-forward network or a recurrent neural network (RNN) does not have the ability to propagate useful gradient information from the output end of the model back to the layers near the input end of the model.
#
# It results in models with many layers being rendered unable to learn on a specific dataset. It could even cause models with many layers to prematurely converge to a substandard solution.
#
# When the backpropagation algorithm advances downwards(or backward) going from the output layer to the input layer, the gradients tend to shrink, becoming smaller and smaller till they approach zero. This ends up leaving the weights of the initial or lower layers practically unchanged. In this situation, the gradient descent does not ever end up converging to the optimum.
#
# Vanishing gradient does not necessarily imply that the gradient vector is all zero (with the exception of numerical overflow). It implies that the gradients are minuscule, which would cause the learning to be very slow.

# %% [markdown]
# Some methods that are proposed to overcome the vanishing gradient problem:
#
# * Residual neural networks (ResNets)
# * Multi-level hierarchy
# * Long short term memory (LSTM)
# * Faster hardware
# * ReLU
# * Batch normalization
#
#
# ##### 1. Residual neural networks (ResNets)
# This is one of the most effective techniques that you can use to overcome the vanishing gradient problem. Before ResNets, a deeper network would have a higher degree of training error than a shallow network.
#
# A backpropagation algorithm each weight of the neural network in a manner that causes it to take a step in the direction along which the loss decreases. This direction is the gradient of the weight (concerning the loss).
#
# You can use the chain rule to find this gradient for each weight. You can find it by multiplying the local gradient by the gradient flowing from ahead.
#
# As the gradient flows backward to the  initial layers, this value goes on getting multiplied by each local gradient. This causes the gradient to keep shrinking, causing the updates to the initial layers to be rather minor, thus increasing the training time substantially. This problem could be solved if the local gradient managed to become 1.
#
# This can be achieved by using the identity function as its derivative would always be 1. So, the gradient would not decrease in value because the local gradient is 1.
#
# TheResNet architecture does not allow the vanishing gradient problem to occur. It has skip connections that function as gradient superhighways which allow the gradient to flow unhindered. It makes it possible for gradients to propagate to deep layers before they can are attenuated to small or zero values.
#
# ##### 2. ReLU
# Here, we replace the typical sigmoidal activation functions used for node output with with a new function: f(x) = max(0, x). This activation only saturates in one direction and thus it is more resilient to the problem of vanishing of gradients.
#
# ReLU is widely used because it maps x to max(0,x) and does not squash the inputs to a small range though it squashes all the negative inputs to zero.
#
# However, ReLU is not the best option for the intermediate layers of the network in certain cases. There is the problem of dying ReLUs in which some neurons just end up dying out. This means that they end up throwing 0 as outputs with the advancement in training.
#
# Some alternative functions of the ReLU that overcome the vanishing gradient problem when used as activation for the intermediate layers of the network include LReLU, PReLU, ELU, SELU.
#
# ##### 3. Multi-level hierarchy
# Multi-level hierarchy involves pre-training a single layer at a time and then performing backpropagation for fine-tuning.
#
# ##### 4. Long Short Term Memory
# Long Short Term Memory (LSTM) was created specifically for the purpose of preventing the vanishing gradient problem. It manages to do that with the Constant Error Carousel (CEC). However, even in an LSTM, the gradients do tend to vanish; they just vanish at a far slower pace than they do in regular recurring neural networks.
#
# ##### 5. Batch normalization
# The internal covariate shift problem is somewhat involved in the exploding gradient problem. Batch normalization can solve this problem. It involves normalizing the activations of each layer, making it possible for every layer to learn on a more stable distribution of inputs, thereby accelerating the training of the network.

# %% [markdown]
# ### III. Explain the difference between simple RNNs, LSTM, and GRU. In what situations might each type of RNN be most appropriate?

# %% [markdown]
# ##### 1. Simple RNNs:
# Simple RNNs are the basic form of RNNs, where the hidden state at each time step is calculated based on the current input and the previous hidden state. However, simple RNNs suffer from the vanishing gradient problem, limiting their ability to capture long-term dependencies. Simple RNNs are most appropriate for tasks where short-term dependencies or local patterns are important, such as language modeling for short sentences or sequence classification with limited context.
#
# ##### 2. LSTM (Long Short-Term Memory):
# LSTM networks were introduced to address the vanishing gradient problem in RNNs by incorporating memory cells and gating mechanisms. LSTM has an internal memory state that allows the network to selectively retain or forget information over time. It consists of three gates: the input gate, forget gate, and output gate. These gates control the flow of information and gradients, enabling LSTMs to capture long-term dependencies effectively. LSTMs are particularly useful for tasks that require modeling complex sequences with long-term dependencies, such as language translation, sentiment analysis, or speech recognition.
#
# ##### 3. GRU (Gated Recurrent Unit):
# GRU is another variant of RNNs that also addresses the vanishing gradient problem. GRU simplifies the LSTM architecture by combining the memory cell and hidden state into a single "update gate." It also introduces a "reset gate" to control the information flow and gradients. GRU has fewer parameters than LSTM, making it computationally more efficient. GRUs perform similarly to LSTMs in capturing long-term dependencies and are especially useful when computational resources are a concern or when dealing with moderately complex sequential tasks.
#
# In summary, the choice between simple RNNs, LSTM, and GRU depends on the specific characteristics of the problem and data:
#
# * Use simple RNNs when the task involves short-term dependencies and local patterns, and when computational resources are limited.
#
# * Use LSTM when dealing with complex sequences that require capturing long-term dependencies, especially in tasks such as language translation, sentiment analysis, or speech recognition.
#
# * Use GRU when computational efficiency is a concern, or when the task involves moderately complex sequential dependencies and long-term context.

# %% [markdown]
# ### IV. Explain how RNNs are trained using backpropagation through time (BPTT). What are some of the challenges associated with training RNNs, and how can these challenges be addressed?

# %% [markdown]
# Recurrent Neural Networks (RNNs) are trained using a variant of backpropagation called Backpropagation Through Time (BPTT). BPTT extends the traditional backpropagation algorithm to handle the temporal nature of sequential data and recurrent connections in RNNs. Here's an overview of how BPTT works:
#
# ##### 1. Forward Pass:
# The input sequence is fed to the RNN one time step at a time. The hidden state at each time step is computed based on the current input and the previous hidden state. The output at each time step can be obtained from the hidden state using an output layer or by directly using the hidden state.
#
# ##### 2. Loss Calculation:
# The output at each time step is compared to the target output to compute the loss. The losses at each time step are usually summed or averaged to obtain a single loss value for the entire sequence.
#
# ##### 3. Backward Pass:
# The gradients are computed by propagating the loss backward through time. Starting from the final time step, the gradients are calculated with respect to the parameters of the model, including the weights connecting the input to the hidden state and the weights connecting the hidden state to itself. The gradients are accumulated over all time steps.
#
# ##### 4. Gradient Update:
# Once the gradients have been computed, the parameters of the RNN are updated using an optimization algorithm such as stochastic gradient descent (SGD) or Adam. The gradients are used to determine the direction and magnitude of the updates.
#
# Challenges associated with training RNNs using BPTT:
#
# ##### 1. Vanishing and Exploding Gradients:
# RNNs are prone to the vanishing and exploding gradient problems, where the gradients diminish or explode as they propagate through time. This can result in unstable training or difficulties in capturing long-term dependencies. Techniques like gradient clipping, careful weight initialization, and the use of specialized architectures like LSTM and GRU can help alleviate these issues.
#
# ##### 2. Training Time and Computational Complexity:
# Training RNNs can be computationally expensive and time-consuming, especially for long sequences or deep architectures. Parallelization techniques, such as mini-batch processing and GPU utilization, can speed up training. Additionally, techniques like truncated BPTT, where the sequence is split into shorter subsequences, can reduce the computational burden.
#
# ##### 3. Overfitting:
# RNNs are prone to overfitting, especially when the model capacity is high and the training data is limited. Regularization techniques like dropout and weight decay can help mitigate overfitting in RNNs.
#
# ##### 4. Choosing Optimal Sequence Length:
# The length of the sequence to use during training is an important consideration. Using very long sequences can lead to memory and computational limitations, while very short sequences may not capture the desired dependencies. Finding an appropriate sequence length or utilizing techniques like bucketing or padding can address this challenge.
#
# ##### 5. Exploration of Hyperparameters:
# RNN training involves tuning various hyperparameters, such as learning rate, batch size, and regularization strength. Efficient hyperparameter search techniques like grid search, random search, or Bayesian optimization can help find optimal configurations.
#
# Addressing these challenges often requires a combination of careful architecture design, appropriate regularization techniques, efficient optimization algorithms, and hyperparameter tuning. It is essential to experiment with different approaches and iterate to find the best solutions for training RNNs effectively.

# %% [markdown]
# ### V. What happens to the gradient if you backpropagate through a long sequence?

# %% [markdown]
# When backpropagating through a long sequence in a Recurrent Neural Network (RNN), the gradients can suffer from the vanishing or exploding gradient problem. The behavior of the gradient depends on the specific RNN architecture, activation functions, and training settings. Here's an overview of what can happen:
#
# ##### 1. Vanishing Gradient:
# In some cases, the gradients may gradually diminish as they propagate through time. This is known as the vanishing gradient problem. When the gradients become very small, the updates to the network's parameters become negligible, and the network fails to learn or capture long-term dependencies effectively. The vanishing gradient problem is more pronounced in traditional RNNs with simple activation functions like the sigmoid function.
#
# ##### 2. Exploding Gradient:
# In other cases, the gradients can grow exponentially as they propagate through time. This is referred to as the exploding gradient problem. When the gradients become extremely large, weight updates can become unstable, and the network parameters may diverge. The exploding gradient problem is especially common when the network has unstable dynamics or when the weights are initialized poorly.
#
# The vanishing and exploding gradient problems hinder the training process and make it difficult for RNNs to capture long-term dependencies accurately. As a result, it becomes challenging to propagate information effectively over long sequences.
#
# To mitigate these issues, several techniques have been developed:
#
# ##### 1. Gradient Clipping:
# Gradient clipping involves rescaling the gradients if they exceed a predefined threshold. By limiting the magnitude of the gradients, gradient clipping helps prevent the exploding gradient problem and stabilizes the training process.
#
# ##### 2. Initialization Strategies:
# Proper initialization of the network's weights can alleviate the vanishing and exploding gradient problems. Techniques like Xavier initialization or He initialization help set the initial weights to appropriate scales, improving the stability of gradient propagation.
#
# ##### 3. Gated Architectures:
# Specialized RNN architectures like Long Short-Term Memory (LSTM) and Gated Recurrent Unit (GRU) have gating mechanisms that allow the network to control the flow of information over time. These architectures are designed to alleviate the vanishing gradient problem and can better capture long-term dependencies.
#
# ##### 4. Truncated Backpropagation Through Time:
# In practice, training an RNN on very long sequences can be computationally expensive and suffer from memory limitations. Truncated Backpropagation Through Time involves breaking the long sequence into shorter subsequences and performing backpropagation on each subsequence separately. This helps address the computational challenges associated with training on long sequences.
#
# By employing these techniques, the vanishing and exploding gradient problems can be mitigated, improving the training stability and the RNN's ability to capture long-term dependencies effectively.

# %% [markdown]
# ### VI. Train a network using simple RNN cells.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from keras import optimizers
from sklearn.model_selection import train_test_split 
from matplotlib import pyplot as plt
# import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, GRU, LSTM, Bidirectional
from tabulate import tabulate

dataset = pd.read_csv('Human_activity_Dataset.csv')     # shape = (10299, 563)

dataset = dataset.drop(columns=['subject/Participant'])

dataset = pd.get_dummies(dataset, columns=['Activity'])
dataset_train, dataset_valid_test = train_test_split(dataset, test_size=0.4)
dataset_valid, dataset_test = train_test_split(dataset_valid_test, test_size=0.5)

labels_train = dataset_train[['Activity_LAYING', 'Activity_SITTING', 'Activity_STANDING', 
                              'Activity_WALKING', 'Activity_WALKING_DOWNSTAIRS', 'Activity_WALKING_UPSTAIRS']]

labels_valid = dataset_valid[['Activity_LAYING', 'Activity_SITTING', 'Activity_STANDING', 
                              'Activity_WALKING', 'Activity_WALKING_DOWNSTAIRS', 'Activity_WALKING_UPSTAIRS']]

labels_test = dataset_test[['Activity_LAYING', 'Activity_SITTING', 'Activity_STANDING', 
                            'Activity_WALKING', 'Activity_WALKING_DOWNSTAIRS', 'Activity_WALKING_UPSTAIRS']]

features_train = dataset_train.drop(columns=labels_train)
features_valid = dataset_valid.drop(columns=labels_valid)
features_test = dataset_test.drop(columns=labels_test)

input_neuron_num = (features_train).shape[1]           # 561:   excluded columns: 'Activity' and 'subject/Participant'    
output_neuron_num = 6                                  # 6:     There are six neurons in the output layer.

# %%
features_train_3d = np.expand_dims(features_train, axis=1)
features_valid_3d = np.expand_dims(features_valid, axis=1)
features_test_3d = np.expand_dims(features_test, axis=1)

epoch_size = 100
batch_size = 128

# Define the Simple RNN model
model_simple_rnn = Sequential(name='Simple_RNN')
model_simple_rnn.add(SimpleRNN(128, 
                               input_shape=(None, input_neuron_num), name='Hidden_Layer'))
model_simple_rnn.add(Dense(output_neuron_num, 
                           activation='softmax', name='Output_Layer'))

# Compile the Simple RNN model
model_simple_rnn.compile(loss='categorical_crossentropy', 
                         optimizer='adam', 
                         metrics=['accuracy'])

# Train the Simple RNN model
result_hist_simple_rnn = model_simple_rnn.fit(features_train_3d, 
                                              labels_train, 
                                              epochs=epoch_size, 
                                              batch_size=batch_size, 
                                              validation_data=(features_valid_3d, labels_valid))

pd.DataFrame(result_hist_simple_rnn.history).plot(figsize=(10, 5), 
                                                  grid=True, 
                                                  xlabel="Epoch", 
                                                  ylabel="Loss / Accuracy")
plt.show()

simple_rnn_eval = model_simple_rnn.evaluate(features_test_3d, 
                                            labels_test)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 1s 8ms/step - loss: 0.7367 - accuracy: 0.7394 - val_loss: 0.3696 - val_accuracy: 0.9005
# Epoch 2/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.2808 - accuracy: 0.9157 - val_loss: 0.2359 - val_accuracy: 0.9257
# Epoch 3/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1907 - accuracy: 0.9435 - val_loss: 0.1785 - val_accuracy: 0.9413
# Epoch 4/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1509 - accuracy: 0.9558 - val_loss: 0.1615 - val_accuracy: 0.9447
# Epoch 5/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1263 - accuracy: 0.9613 - val_loss: 0.1148 - val_accuracy: 0.9670
# Epoch 6/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1117 - accuracy: 0.9654 - val_loss: 0.1323 - val_accuracy: 0.9568
# Epoch 7/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.1076 - accuracy: 0.9631 - val_loss: 0.0983 - val_accuracy: 0.9699
# Epoch 8/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.1181 - accuracy: 0.9531 - val_loss: 0.0906 - val_accuracy: 0.9680
# Epoch 9/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0838 - accuracy: 0.9714 - val_loss: 0.1775 - val_accuracy: 0.9243
# Epoch 10/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0871 - accuracy: 0.9688 - val_loss: 0.0893 - val_accuracy: 0.9680
# Epoch 11/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0710 - accuracy: 0.9767 - val_loss: 0.0798 - val_accuracy: 0.9733
# Epoch 12/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0667 - accuracy: 0.9785 - val_loss: 0.0701 - val_accuracy: 0.9772
# Epoch 13/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9777 - val_loss: 0.0657 - val_accuracy: 0.9796
# Epoch 14/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9780 - val_loss: 0.0905 - val_accuracy: 0.9646
# Epoch 15/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0589 - accuracy: 0.9791 - val_loss: 0.0638 - val_accuracy: 0.9811
# Epoch 16/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0620 - accuracy: 0.9777 - val_loss: 0.0796 - val_accuracy: 0.9680
# Epoch 17/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0594 - accuracy: 0.9782 - val_loss: 0.0628 - val_accuracy: 0.9796
# Epoch 18/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0532 - accuracy: 0.9803 - val_loss: 0.0731 - val_accuracy: 0.9714
# Epoch 19/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0700 - accuracy: 0.9723 - val_loss: 0.0712 - val_accuracy: 0.9728
# Epoch 20/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9811 - val_loss: 0.0552 - val_accuracy: 0.9786
# Epoch 21/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 0.9849 - val_loss: 0.0528 - val_accuracy: 0.9806
# Epoch 22/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9859 - val_loss: 0.1199 - val_accuracy: 0.9466
# Epoch 23/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0455 - accuracy: 0.9851 - val_loss: 0.0559 - val_accuracy: 0.9801
# Epoch 24/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0407 - accuracy: 0.9879 - val_loss: 0.0587 - val_accuracy: 0.9762
# Epoch 25/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0420 - accuracy: 0.9862 - val_loss: 0.0498 - val_accuracy: 0.9830
# Epoch 26/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0540 - accuracy: 0.9786 - val_loss: 0.0721 - val_accuracy: 0.9714
# Epoch 27/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 0.9853 - val_loss: 0.0627 - val_accuracy: 0.9777
# Epoch 28/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0444 - accuracy: 0.9816 - val_loss: 0.0606 - val_accuracy: 0.9772
# Epoch 29/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 0.9877 - val_loss: 0.0582 - val_accuracy: 0.9786
# Epoch 30/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0432 - accuracy: 0.9845 - val_loss: 0.0478 - val_accuracy: 0.9816
# Epoch 31/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 0.9890 - val_loss: 0.0534 - val_accuracy: 0.9782
# Epoch 32/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0354 - accuracy: 0.9875 - val_loss: 0.0569 - val_accuracy: 0.9786
# Epoch 33/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0361 - accuracy: 0.9880 - val_loss: 0.0478 - val_accuracy: 0.9840
# Epoch 34/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 0.9883 - val_loss: 0.0467 - val_accuracy: 0.9835
# Epoch 35/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0349 - accuracy: 0.9871 - val_loss: 0.0623 - val_accuracy: 0.9767
# Epoch 36/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 0.9869 - val_loss: 0.0593 - val_accuracy: 0.9762
# Epoch 37/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0345 - accuracy: 0.9877 - val_loss: 0.0430 - val_accuracy: 0.9835
# Epoch 38/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0449 - accuracy: 0.9833 - val_loss: 0.0537 - val_accuracy: 0.9796
# Epoch 39/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0270 - accuracy: 0.9921 - val_loss: 0.0446 - val_accuracy: 0.9835
# Epoch 40/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 0.9872 - val_loss: 0.0619 - val_accuracy: 0.9772
# Epoch 41/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0373 - accuracy: 0.9854 - val_loss: 0.0581 - val_accuracy: 0.9767
# Epoch 42/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 0.9883 - val_loss: 0.0461 - val_accuracy: 0.9850
# Epoch 43/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0262 - accuracy: 0.9913 - val_loss: 0.0425 - val_accuracy: 0.9859
# Epoch 44/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0323 - accuracy: 0.9883 - val_loss: 0.0528 - val_accuracy: 0.9786
# Epoch 45/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0249 - accuracy: 0.9930 - val_loss: 0.0646 - val_accuracy: 0.9748
# Epoch 46/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0559 - accuracy: 0.9770 - val_loss: 0.0411 - val_accuracy: 0.9859
# Epoch 47/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0303 - accuracy: 0.9895 - val_loss: 0.0396 - val_accuracy: 0.9850
# Epoch 48/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 0.9885 - val_loss: 0.0417 - val_accuracy: 0.9864
# Epoch 49/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0224 - accuracy: 0.9924 - val_loss: 0.0435 - val_accuracy: 0.9845
# Epoch 50/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0347 - accuracy: 0.9867 - val_loss: 0.0398 - val_accuracy: 0.9850
# Epoch 51/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9939 - val_loss: 0.0392 - val_accuracy: 0.9859
# Epoch 52/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0217 - accuracy: 0.9919 - val_loss: 0.0398 - val_accuracy: 0.9854
# Epoch 53/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9935 - val_loss: 0.0460 - val_accuracy: 0.9830
# Epoch 54/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.0395 - val_accuracy: 0.9845
# Epoch 55/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0208 - accuracy: 0.9926 - val_loss: 0.0397 - val_accuracy: 0.9854
# Epoch 56/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.0389 - val_accuracy: 0.9850
# Epoch 57/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0162 - accuracy: 0.9960 - val_loss: 0.0408 - val_accuracy: 0.9859
# Epoch 58/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0239 - accuracy: 0.9903 - val_loss: 0.0384 - val_accuracy: 0.9854
# Epoch 59/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9932 - val_loss: 0.0372 - val_accuracy: 0.9854
# Epoch 60/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9942 - val_loss: 0.0435 - val_accuracy: 0.9835
# Epoch 61/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 0.0429 - val_accuracy: 0.9859
# Epoch 62/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.0345 - val_accuracy: 0.9864
# Epoch 63/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0164 - accuracy: 0.9950 - val_loss: 0.0365 - val_accuracy: 0.9879
# Epoch 64/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0882 - val_accuracy: 0.9675
# Epoch 65/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0197 - accuracy: 0.9934 - val_loss: 0.0353 - val_accuracy: 0.9869
# Epoch 66/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 0.9945 - val_loss: 0.0367 - val_accuracy: 0.9879
# Epoch 67/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0143 - accuracy: 0.9960 - val_loss: 0.0369 - val_accuracy: 0.9864
# Epoch 68/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 0.9898 - val_loss: 0.0483 - val_accuracy: 0.9825
# Epoch 69/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9963 - val_loss: 0.0341 - val_accuracy: 0.9864
# Epoch 70/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 0.9972 - val_loss: 0.0413 - val_accuracy: 0.9840
# Epoch 71/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 0.9966 - val_loss: 0.0454 - val_accuracy: 0.9830
# Epoch 72/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 0.9951 - val_loss: 0.0421 - val_accuracy: 0.9840
# Epoch 73/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9929 - val_loss: 0.0365 - val_accuracy: 0.9864
# Epoch 74/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.0458 - val_accuracy: 0.9825
# Epoch 75/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.0333 - val_accuracy: 0.9874
# Epoch 76/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9982 - val_loss: 0.0351 - val_accuracy: 0.9879
# Epoch 77/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.9932 - val_loss: 0.0338 - val_accuracy: 0.9893
# Epoch 78/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0088 - accuracy: 0.9985 - val_loss: 0.0329 - val_accuracy: 0.9893
# Epoch 79/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0322 - val_accuracy: 0.9893
# Epoch 80/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9987 - val_loss: 0.0328 - val_accuracy: 0.9874
# Epoch 81/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0077 - accuracy: 0.9987 - val_loss: 0.0415 - val_accuracy: 0.9850
# Epoch 82/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.0340 - val_accuracy: 0.9874
# Epoch 83/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0111 - accuracy: 0.9966 - val_loss: 0.0349 - val_accuracy: 0.9864
# Epoch 84/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.0343 - val_accuracy: 0.9869
# Epoch 85/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0398 - val_accuracy: 0.9859
# Epoch 86/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9958 - val_loss: 0.0332 - val_accuracy: 0.9869
# Epoch 87/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 0.9992 - val_loss: 0.0323 - val_accuracy: 0.9883
# Epoch 88/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9992 - val_loss: 0.0339 - val_accuracy: 0.9864
# Epoch 89/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 0.9992 - val_loss: 0.0362 - val_accuracy: 0.9845
# Epoch 90/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.0314 - val_accuracy: 0.9888
# Epoch 91/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0102 - accuracy: 0.9976 - val_loss: 0.0342 - val_accuracy: 0.9869
# Epoch 92/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0062 - accuracy: 0.9985 - val_loss: 0.0397 - val_accuracy: 0.9859
# Epoch 93/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 0.9998 - val_loss: 0.0331 - val_accuracy: 0.9874
# Epoch 94/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9994 - val_loss: 0.0418 - val_accuracy: 0.9850
# Epoch 95/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 0.9950 - val_loss: 0.0518 - val_accuracy: 0.9816
# Epoch 96/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.0329 - val_accuracy: 0.9869
# Epoch 97/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 0.9995 - val_loss: 0.0308 - val_accuracy: 0.9893
# Epoch 98/100
# 49/49 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.0302 - val_accuracy: 0.9883
# Epoch 99/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0341 - val_accuracy: 0.9874
# Epoch 100/100
# 49/49 [==============================] - 0s 3ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0333 - val_accuracy: 0.9879
# 65/65 [==============================] - 0s 1ms/step - loss: 0.0449 - accuracy: 0.9854

# %% [markdown]
# ### VII. Train a network using LSTM Cells or GRU (you can use both).

# %%
# Define the GRU model
model_gru = Sequential(name='GRU')
model_gru.add(GRU(128, 
              input_shape=(None, input_neuron_num), 
              name='Hidden_Layer'))
model_gru.add(Dense(output_neuron_num, 
                    activation='softmax', 
                    name='Output_Layer'))

# Compile the GRU model
model_gru.compile(loss='categorical_crossentropy', 
                  optimizer='adam', 
                  metrics=['accuracy'])

# Train the GRU model
result_hist_gru = model_gru.fit(features_train_3d, 
                                labels_train, 
                                epochs=epoch_size, 
                                batch_size=batch_size, 
                                validation_data=(features_valid_3d, labels_valid))

pd.DataFrame(result_hist_gru.history).plot(figsize=(10, 5), 
                                           grid=True, 
                                           xlabel="Epoch", 
                                           ylabel="Loss / Accuracy")
plt.show()

gru_eval = model_gru.evaluate(features_test_3d, 
                              labels_test)

# Define the LSTM model
model_lstm = Sequential(name='LSTM')
model_lstm.add(LSTM(128, 
                    input_shape=(None, input_neuron_num), 
                    name='Input_Layer'))
model_lstm.add(Dense(output_neuron_num, 
                     activation='softmax', 
                     name='Output_Layer'))

# Compile the LSTM model
model_lstm.compile(loss='categorical_crossentropy', 
                   optimizer='adam', 
                   metrics=['accuracy'])

# Train the LSTM model
result_hist_lstm = model_lstm.fit(features_train_3d, 
                                  labels_train, 
                                  epochs=epoch_size, 
                                  batch_size=batch_size, 
                                  validation_data=(features_valid_3d, labels_valid))

pd.DataFrame(result_hist_lstm.history).plot(figsize=(10, 5), 
                                            grid=True, 
                                            xlabel="Epoch", 
                                            ylabel="Loss / Accuracy")
plt.show()

lstm_eval = model_lstm.evaluate(features_test_3d, 
                                labels_test)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 2s 13ms/step - loss: 0.6807 - accuracy: 0.7699 - val_loss: 0.3684 - val_accuracy: 0.8505
# Epoch 2/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.2483 - accuracy: 0.9173 - val_loss: 0.2160 - val_accuracy: 0.9262
# Epoch 3/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1697 - accuracy: 0.9447 - val_loss: 0.2055 - val_accuracy: 0.9228
# Epoch 4/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.1402 - accuracy: 0.9537 - val_loss: 0.1244 - val_accuracy: 0.9631
# Epoch 5/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.9636 - val_loss: 0.1138 - val_accuracy: 0.9660
# Epoch 6/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0948 - accuracy: 0.9697 - val_loss: 0.1224 - val_accuracy: 0.9578
# Epoch 7/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0900 - accuracy: 0.9714 - val_loss: 0.0921 - val_accuracy: 0.9670
# Epoch 8/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0803 - accuracy: 0.9733 - val_loss: 0.0807 - val_accuracy: 0.9728
# Epoch 9/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.9748 - val_loss: 0.0750 - val_accuracy: 0.9757
# Epoch 10/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0661 - accuracy: 0.9782 - val_loss: 0.0976 - val_accuracy: 0.9636
# Epoch 11/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0660 - accuracy: 0.9765 - val_loss: 0.0679 - val_accuracy: 0.9767
# Epoch 12/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0660 - accuracy: 0.9770 - val_loss: 0.0762 - val_accuracy: 0.9714
# Epoch 13/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0561 - accuracy: 0.9809 - val_loss: 0.0627 - val_accuracy: 0.9767
# Epoch 14/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0583 - accuracy: 0.9791 - val_loss: 0.0613 - val_accuracy: 0.9796
# Epoch 15/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0595 - accuracy: 0.9786 - val_loss: 0.0693 - val_accuracy: 0.9748
# Epoch 16/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0615 - accuracy: 0.9782 - val_loss: 0.0623 - val_accuracy: 0.9796
# Epoch 17/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0539 - accuracy: 0.9801 - val_loss: 0.0593 - val_accuracy: 0.9825
# Epoch 18/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0488 - accuracy: 0.9845 - val_loss: 0.0637 - val_accuracy: 0.9796
# Epoch 19/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0715 - accuracy: 0.9728 - val_loss: 0.1285 - val_accuracy: 0.9500
# Epoch 20/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0487 - accuracy: 0.9832 - val_loss: 0.0516 - val_accuracy: 0.9806
# Epoch 21/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0409 - accuracy: 0.9869 - val_loss: 0.0595 - val_accuracy: 0.9772
# Epoch 22/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0427 - accuracy: 0.9843 - val_loss: 0.0567 - val_accuracy: 0.9752
# Epoch 23/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0464 - accuracy: 0.9812 - val_loss: 0.0520 - val_accuracy: 0.9830
# Epoch 24/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0418 - accuracy: 0.9849 - val_loss: 0.0493 - val_accuracy: 0.9830
# Epoch 25/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0478 - accuracy: 0.9806 - val_loss: 0.0527 - val_accuracy: 0.9791
# Epoch 26/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0412 - accuracy: 0.9856 - val_loss: 0.0490 - val_accuracy: 0.9816
# Epoch 27/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0446 - accuracy: 0.9830 - val_loss: 0.0752 - val_accuracy: 0.9675
# Epoch 28/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.9864 - val_loss: 0.0482 - val_accuracy: 0.9854
# Epoch 29/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0350 - accuracy: 0.9867 - val_loss: 0.0461 - val_accuracy: 0.9830
# Epoch 30/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 0.9880 - val_loss: 0.0451 - val_accuracy: 0.9854
# Epoch 31/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9811 - val_loss: 0.0461 - val_accuracy: 0.9825
# Epoch 32/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9883 - val_loss: 0.0521 - val_accuracy: 0.9791
# Epoch 33/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0365 - accuracy: 0.9864 - val_loss: 0.0493 - val_accuracy: 0.9820
# Epoch 34/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0499 - accuracy: 0.9799 - val_loss: 0.0745 - val_accuracy: 0.9689
# Epoch 35/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9887 - val_loss: 0.0543 - val_accuracy: 0.9782
# Epoch 36/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0299 - accuracy: 0.9880 - val_loss: 0.0449 - val_accuracy: 0.9859
# Epoch 37/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0266 - accuracy: 0.9914 - val_loss: 0.0581 - val_accuracy: 0.9762
# Epoch 38/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0347 - accuracy: 0.9864 - val_loss: 0.0466 - val_accuracy: 0.9850
# Epoch 39/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.0523 - val_accuracy: 0.9811
# Epoch 40/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9900 - val_loss: 0.0408 - val_accuracy: 0.9869
# Epoch 41/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 0.9896 - val_loss: 0.0501 - val_accuracy: 0.9801
# Epoch 42/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0334 - accuracy: 0.9867 - val_loss: 0.0413 - val_accuracy: 0.9864
# Epoch 43/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0249 - accuracy: 0.9916 - val_loss: 0.0489 - val_accuracy: 0.9801
# Epoch 44/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0225 - accuracy: 0.9939 - val_loss: 0.0405 - val_accuracy: 0.9869
# Epoch 45/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0241 - accuracy: 0.9917 - val_loss: 0.0509 - val_accuracy: 0.9796
# Epoch 46/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0411 - accuracy: 0.9848 - val_loss: 0.0614 - val_accuracy: 0.9762
# Epoch 47/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9903 - val_loss: 0.0523 - val_accuracy: 0.9811
# Epoch 48/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 0.9921 - val_loss: 0.0385 - val_accuracy: 0.9874
# Epoch 49/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9942 - val_loss: 0.0417 - val_accuracy: 0.9830
# Epoch 50/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0270 - accuracy: 0.9905 - val_loss: 0.0454 - val_accuracy: 0.9811
# Epoch 51/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 0.0366 - val_accuracy: 0.9869
# Epoch 52/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9948 - val_loss: 0.0384 - val_accuracy: 0.9879
# Epoch 53/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.0384 - val_accuracy: 0.9869
# Epoch 54/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 0.9930 - val_loss: 0.0573 - val_accuracy: 0.9757
# Epoch 55/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0194 - accuracy: 0.9935 - val_loss: 0.0761 - val_accuracy: 0.9718
# Epoch 56/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9947 - val_loss: 0.0347 - val_accuracy: 0.9859
# Epoch 57/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0390 - val_accuracy: 0.9835
# Epoch 58/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 0.9930 - val_loss: 0.1182 - val_accuracy: 0.9587
# Epoch 59/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0259 - accuracy: 0.9906 - val_loss: 0.0364 - val_accuracy: 0.9845
# Epoch 60/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9963 - val_loss: 0.0505 - val_accuracy: 0.9816
# Epoch 61/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0172 - accuracy: 0.9934 - val_loss: 0.0336 - val_accuracy: 0.9879
# Epoch 62/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0201 - accuracy: 0.9924 - val_loss: 0.1013 - val_accuracy: 0.9655
# Epoch 63/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 0.9906 - val_loss: 0.1790 - val_accuracy: 0.9379
# Epoch 64/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0216 - accuracy: 0.9917 - val_loss: 0.0362 - val_accuracy: 0.9864
# Epoch 65/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9972 - val_loss: 0.0315 - val_accuracy: 0.9879
# Epoch 66/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9977 - val_loss: 0.0314 - val_accuracy: 0.9879
# Epoch 67/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9981 - val_loss: 0.0372 - val_accuracy: 0.9859
# Epoch 68/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9984 - val_loss: 0.0298 - val_accuracy: 0.9898
# Epoch 69/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9976 - val_loss: 0.0350 - val_accuracy: 0.9874
# Epoch 70/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.9948 - val_loss: 0.0561 - val_accuracy: 0.9762
# Epoch 71/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.0310 - val_accuracy: 0.9888
# Epoch 72/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.0314 - val_accuracy: 0.9883
# Epoch 73/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9966 - val_loss: 0.0545 - val_accuracy: 0.9786
# Epoch 74/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0222 - accuracy: 0.9911 - val_loss: 0.0400 - val_accuracy: 0.9859
# Epoch 75/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9979 - val_loss: 0.0320 - val_accuracy: 0.9888
# Epoch 76/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9985 - val_loss: 0.0321 - val_accuracy: 0.9903
# Epoch 77/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 0.0357 - val_accuracy: 0.9859
# Epoch 78/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9989 - val_loss: 0.0322 - val_accuracy: 0.9874
# Epoch 79/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9992 - val_loss: 0.0314 - val_accuracy: 0.9874
# Epoch 80/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.0347 - val_accuracy: 0.9879
# Epoch 81/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 0.9922 - val_loss: 0.0655 - val_accuracy: 0.9748
# Epoch 82/100
# 49/49 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0321 - val_accuracy: 0.9883
# Epoch 83/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9982 - val_loss: 0.0277 - val_accuracy: 0.9903
# Epoch 84/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.0291 - val_accuracy: 0.9888
# Epoch 85/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9990 - val_loss: 0.0350 - val_accuracy: 0.9879
# Epoch 86/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0054 - accuracy: 0.9994 - val_loss: 0.0321 - val_accuracy: 0.9874
# Epoch 87/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9998 - val_loss: 0.0299 - val_accuracy: 0.9903
# Epoch 88/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0537 - val_accuracy: 0.9796
# Epoch 89/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9976 - val_loss: 0.0339 - val_accuracy: 0.9869
# Epoch 90/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9948 - val_loss: 0.0328 - val_accuracy: 0.9869
# Epoch 91/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0762 - val_accuracy: 0.9718
# Epoch 92/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9971 - val_loss: 0.0314 - val_accuracy: 0.9888
# Epoch 93/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.0288 - val_accuracy: 0.9908
# Epoch 94/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.0294 - val_accuracy: 0.9898
# Epoch 95/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9998 - val_loss: 0.0388 - val_accuracy: 0.9854
# Epoch 96/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9997 - val_loss: 0.0283 - val_accuracy: 0.9903
# Epoch 97/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0287 - val_accuracy: 0.9898
# Epoch 98/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9997 - val_loss: 0.0351 - val_accuracy: 0.9864
# Epoch 99/100
# 49/49 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.0385 - val_accuracy: 0.9854
# Epoch 100/100
# 49/49 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0285 - val_accuracy: 0.9893
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9859
# Epoch 1/100
# 49/49 [==============================] - 2s 16ms/step - loss: 0.7261 - accuracy: 0.7632 - val_loss: 0.3553 - val_accuracy: 0.8947
# Epoch 2/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.2705 - accuracy: 0.9082 - val_loss: 0.2044 - val_accuracy: 0.9364
# Epoch 3/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1771 - accuracy: 0.9429 - val_loss: 0.1550 - val_accuracy: 0.9476
# Epoch 4/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1396 - accuracy: 0.9539 - val_loss: 0.1248 - val_accuracy: 0.9617
# Epoch 5/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1175 - accuracy: 0.9597 - val_loss: 0.1580 - val_accuracy: 0.9369
# Epoch 6/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1084 - accuracy: 0.9620 - val_loss: 0.1510 - val_accuracy: 0.9369
# Epoch 7/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.1028 - accuracy: 0.9618 - val_loss: 0.0940 - val_accuracy: 0.9650
# Epoch 8/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0798 - accuracy: 0.9712 - val_loss: 0.0809 - val_accuracy: 0.9709
# Epoch 9/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0714 - accuracy: 0.9770 - val_loss: 0.0728 - val_accuracy: 0.9757
# Epoch 10/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0675 - accuracy: 0.9777 - val_loss: 0.0968 - val_accuracy: 0.9631
# Epoch 11/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0670 - accuracy: 0.9777 - val_loss: 0.1027 - val_accuracy: 0.9636
# Epoch 12/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0639 - accuracy: 0.9790 - val_loss: 0.0634 - val_accuracy: 0.9772
# Epoch 13/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0558 - accuracy: 0.9825 - val_loss: 0.0586 - val_accuracy: 0.9777
# Epoch 14/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0541 - accuracy: 0.9796 - val_loss: 0.0604 - val_accuracy: 0.9762
# Epoch 15/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0501 - accuracy: 0.9822 - val_loss: 0.0620 - val_accuracy: 0.9777
# Epoch 16/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0486 - accuracy: 0.9835 - val_loss: 0.0557 - val_accuracy: 0.9791
# Epoch 17/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0465 - accuracy: 0.9833 - val_loss: 0.0638 - val_accuracy: 0.9767
# Epoch 18/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0556 - accuracy: 0.9783 - val_loss: 0.0558 - val_accuracy: 0.9786
# Epoch 19/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0522 - accuracy: 0.9798 - val_loss: 0.1064 - val_accuracy: 0.9578
# Epoch 20/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0558 - accuracy: 0.9790 - val_loss: 0.0499 - val_accuracy: 0.9816
# Epoch 21/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0454 - accuracy: 0.9833 - val_loss: 0.0566 - val_accuracy: 0.9791
# Epoch 22/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0483 - accuracy: 0.9822 - val_loss: 0.0722 - val_accuracy: 0.9718
# Epoch 23/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0500 - accuracy: 0.9799 - val_loss: 0.0752 - val_accuracy: 0.9689
# Epoch 24/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0434 - accuracy: 0.9848 - val_loss: 0.0578 - val_accuracy: 0.9752
# Epoch 25/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0369 - accuracy: 0.9862 - val_loss: 0.0532 - val_accuracy: 0.9816
# Epoch 26/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0436 - accuracy: 0.9840 - val_loss: 0.0486 - val_accuracy: 0.9830
# Epoch 27/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0372 - accuracy: 0.9851 - val_loss: 0.1131 - val_accuracy: 0.9515
# Epoch 28/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0419 - accuracy: 0.9841 - val_loss: 0.0502 - val_accuracy: 0.9801
# Epoch 29/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0483 - accuracy: 0.9806 - val_loss: 0.0635 - val_accuracy: 0.9757
# Epoch 30/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0337 - accuracy: 0.9880 - val_loss: 0.0538 - val_accuracy: 0.9777
# Epoch 31/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0370 - accuracy: 0.9854 - val_loss: 0.0559 - val_accuracy: 0.9782
# Epoch 32/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0354 - accuracy: 0.9872 - val_loss: 0.0671 - val_accuracy: 0.9733
# Epoch 33/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0522 - accuracy: 0.9791 - val_loss: 0.0651 - val_accuracy: 0.9718
# Epoch 34/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0302 - accuracy: 0.9890 - val_loss: 0.0516 - val_accuracy: 0.9796
# Epoch 35/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0328 - accuracy: 0.9877 - val_loss: 0.0431 - val_accuracy: 0.9845
# Epoch 36/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0294 - accuracy: 0.9895 - val_loss: 0.0426 - val_accuracy: 0.9840
# Epoch 37/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0333 - accuracy: 0.9875 - val_loss: 0.0448 - val_accuracy: 0.9825
# Epoch 38/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0257 - accuracy: 0.9914 - val_loss: 0.0415 - val_accuracy: 0.9840
# Epoch 39/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0264 - accuracy: 0.9914 - val_loss: 0.0476 - val_accuracy: 0.9835
# Epoch 40/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0311 - accuracy: 0.9875 - val_loss: 0.0851 - val_accuracy: 0.9650
# Epoch 41/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0306 - accuracy: 0.9895 - val_loss: 0.0466 - val_accuracy: 0.9845
# Epoch 42/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0268 - accuracy: 0.9913 - val_loss: 0.0402 - val_accuracy: 0.9845
# Epoch 43/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0250 - accuracy: 0.9914 - val_loss: 0.0623 - val_accuracy: 0.9762
# Epoch 44/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0391 - accuracy: 0.9848 - val_loss: 0.0388 - val_accuracy: 0.9840
# Epoch 45/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.0455 - val_accuracy: 0.9816
# Epoch 46/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0225 - accuracy: 0.9932 - val_loss: 0.0387 - val_accuracy: 0.9854
# Epoch 47/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0206 - accuracy: 0.9939 - val_loss: 0.0384 - val_accuracy: 0.9859
# Epoch 48/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.0438 - val_accuracy: 0.9825
# Epoch 49/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0240 - accuracy: 0.9922 - val_loss: 0.0676 - val_accuracy: 0.9738
# Epoch 50/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0294 - accuracy: 0.9892 - val_loss: 0.0482 - val_accuracy: 0.9820
# Epoch 51/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0281 - accuracy: 0.9883 - val_loss: 0.0380 - val_accuracy: 0.9859
# Epoch 52/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0190 - accuracy: 0.9939 - val_loss: 0.0402 - val_accuracy: 0.9825
# Epoch 53/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0266 - accuracy: 0.9908 - val_loss: 0.0348 - val_accuracy: 0.9864
# Epoch 54/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0177 - accuracy: 0.9939 - val_loss: 0.0373 - val_accuracy: 0.9854
# Epoch 55/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0163 - accuracy: 0.9958 - val_loss: 0.0360 - val_accuracy: 0.9869
# Epoch 56/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0291 - accuracy: 0.9877 - val_loss: 0.0390 - val_accuracy: 0.9874
# Epoch 57/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0160 - accuracy: 0.9953 - val_loss: 0.0371 - val_accuracy: 0.9879
# Epoch 58/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 0.9943 - val_loss: 0.0346 - val_accuracy: 0.9888
# Epoch 59/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0150 - accuracy: 0.9964 - val_loss: 0.0364 - val_accuracy: 0.9879
# Epoch 60/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0132 - accuracy: 0.9958 - val_loss: 0.0330 - val_accuracy: 0.9874
# Epoch 61/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0149 - accuracy: 0.9955 - val_loss: 0.0316 - val_accuracy: 0.9893
# Epoch 62/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0118 - accuracy: 0.9974 - val_loss: 0.0341 - val_accuracy: 0.9883
# Epoch 63/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0126 - accuracy: 0.9966 - val_loss: 0.0424 - val_accuracy: 0.9835
# Epoch 64/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0142 - accuracy: 0.9953 - val_loss: 0.0518 - val_accuracy: 0.9806
# Epoch 65/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0114 - accuracy: 0.9974 - val_loss: 0.0356 - val_accuracy: 0.9879
# Epoch 66/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.0336 - val_accuracy: 0.9888
# Epoch 67/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 0.9981 - val_loss: 0.0398 - val_accuracy: 0.9835
# Epoch 68/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0133 - accuracy: 0.9953 - val_loss: 0.0565 - val_accuracy: 0.9762
# Epoch 69/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.0541 - val_accuracy: 0.9786
# Epoch 70/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.0342 - val_accuracy: 0.9869
# Epoch 71/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0174 - accuracy: 0.9939 - val_loss: 0.0428 - val_accuracy: 0.9835
# Epoch 72/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0112 - accuracy: 0.9968 - val_loss: 0.0508 - val_accuracy: 0.9777
# Epoch 73/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.0446 - val_accuracy: 0.9830
# Epoch 74/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0148 - accuracy: 0.9951 - val_loss: 0.0402 - val_accuracy: 0.9859
# Epoch 75/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0074 - accuracy: 0.9985 - val_loss: 0.0370 - val_accuracy: 0.9864
# Epoch 76/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0382 - val_accuracy: 0.9845
# Epoch 77/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.0358 - val_accuracy: 0.9869
# Epoch 78/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0160 - accuracy: 0.9940 - val_loss: 0.0506 - val_accuracy: 0.9791
# Epoch 79/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.0305 - val_accuracy: 0.9898
# Epoch 80/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0319 - val_accuracy: 0.9888
# Epoch 81/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 0.9992 - val_loss: 0.0320 - val_accuracy: 0.9883
# Epoch 82/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0053 - accuracy: 0.9994 - val_loss: 0.0366 - val_accuracy: 0.9859
# Epoch 83/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 0.9994 - val_loss: 0.0306 - val_accuracy: 0.9893
# Epoch 84/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 0.9992 - val_loss: 0.0377 - val_accuracy: 0.9864
# Epoch 85/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0055 - accuracy: 0.9992 - val_loss: 0.0313 - val_accuracy: 0.9898
# Epoch 86/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0079 - accuracy: 0.9977 - val_loss: 0.0374 - val_accuracy: 0.9854
# Epoch 87/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0059 - accuracy: 0.9994 - val_loss: 0.0325 - val_accuracy: 0.9888
# Epoch 88/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 0.9984 - val_loss: 0.0320 - val_accuracy: 0.9893
# Epoch 89/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0293 - val_accuracy: 0.9893
# Epoch 90/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0303 - val_accuracy: 0.9898
# Epoch 91/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0312 - val_accuracy: 0.9874
# Epoch 92/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0296 - val_accuracy: 0.9908
# Epoch 93/100
# 49/49 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 0.9977 - val_loss: 0.0297 - val_accuracy: 0.9883
# Epoch 94/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.0367 - val_accuracy: 0.9879
# Epoch 95/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0310 - val_accuracy: 0.9898
# Epoch 96/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0316 - val_accuracy: 0.9874
# Epoch 97/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.0308 - val_accuracy: 0.9898
# Epoch 98/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0378 - val_accuracy: 0.9859
# Epoch 99/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0102 - accuracy: 0.9963 - val_loss: 0.0364 - val_accuracy: 0.9859
# Epoch 100/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 0.0326 - val_accuracy: 0.9898
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9840

# %% [markdown]
# ### VIII. Train a network using bidirectional LSTM or GRU ( you can use both).

# %%
# Define the Bidirectioanl GRU model
model_bi_gru = Sequential(name='Bi_GRU')
model_bi_gru.add(Bidirectional(GRU(128), 
                               input_shape=(None, input_neuron_num), 
                               name='Input_Layer'))
model_bi_gru.add(Dense(output_neuron_num, 
                       activation='softmax',
                       name='Output_Layer'))

# Compile the Bidirectioanl GRU model
model_bi_gru.compile(loss='categorical_crossentropy', 
                     optimizer='adam', 
                     metrics=['accuracy'])

# Train the Bidirectioanl GRU model
result_hist_bi_gru = model_bi_gru.fit(features_train_3d, 
                                      labels_train, 
                                      epochs=epoch_size, 
                                      batch_size=batch_size, 
                                      validation_data=(features_valid_3d, labels_valid))

pd.DataFrame(result_hist_bi_gru.history).plot(figsize=(10, 5), 
                                              grid=True, 
                                              xlabel="Epoch", 
                                              ylabel="Loss / Accuracy")
plt.show()

bi_gru_eval = model_bi_gru.evaluate(features_test_3d, 
                                    labels_test)

# Define the Bidirectioanl LSTM model
model_bi_lstm = Sequential(name='Bi_LSTM')
model_bi_lstm.add(Bidirectional(LSTM(128), 
                                input_shape=(None, input_neuron_num), 
                                name='Input_Layer'))
model_bi_lstm.add(Dense(output_neuron_num, 
                        activation='softmax',
                        name='Output_Layer'))

# Compile the Bidirectioanl LSTM model
model_bi_lstm.compile(loss='categorical_crossentropy', 
                      optimizer='adam', 
                      metrics=['accuracy'])

# Train the Bidirectioanl LSTM model
result_hist_bi_lstm = model_bi_lstm.fit(features_train_3d, 
                                        labels_train, 
                                        epochs=epoch_size, 
                                        batch_size=batch_size, 
                                        validation_data=(features_valid_3d, labels_valid))

pd.DataFrame(result_hist_bi_lstm.history).plot(figsize=(10, 5), 
                                               grid=True, 
                                               xlabel="Epoch", 
                                               ylabel="Loss / Accuracy")
plt.show()

bi_lstm_eval = model_bi_lstm.evaluate(features_test_3d, 
                                      labels_test)
# Out:
# Epoch 1/100
# 49/49 [==============================] - 4s 24ms/step - loss: 0.5674 - accuracy: 0.7975 - val_loss: 0.2835 - val_accuracy: 0.8903
# Epoch 2/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.2067 - accuracy: 0.9281 - val_loss: 0.1563 - val_accuracy: 0.9505
# Epoch 3/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.1408 - accuracy: 0.9511 - val_loss: 0.1293 - val_accuracy: 0.9553
# Epoch 4/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1075 - accuracy: 0.9634 - val_loss: 0.1190 - val_accuracy: 0.9607
# Epoch 5/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.1086 - accuracy: 0.9625 - val_loss: 0.1050 - val_accuracy: 0.9660
# Epoch 6/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0994 - accuracy: 0.9641 - val_loss: 0.0836 - val_accuracy: 0.9728
# Epoch 7/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0710 - accuracy: 0.9754 - val_loss: 0.0695 - val_accuracy: 0.9791
# Epoch 8/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0751 - accuracy: 0.9720 - val_loss: 0.0805 - val_accuracy: 0.9733
# Epoch 9/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0712 - accuracy: 0.9741 - val_loss: 0.0752 - val_accuracy: 0.9718
# Epoch 10/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0826 - accuracy: 0.9678 - val_loss: 0.0646 - val_accuracy: 0.9786
# Epoch 11/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0614 - accuracy: 0.9775 - val_loss: 0.1238 - val_accuracy: 0.9437
# Epoch 12/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0744 - accuracy: 0.9749 - val_loss: 0.0642 - val_accuracy: 0.9757
# Epoch 13/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0542 - accuracy: 0.9782 - val_loss: 0.0785 - val_accuracy: 0.9670
# Epoch 14/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0546 - accuracy: 0.9794 - val_loss: 0.0560 - val_accuracy: 0.9777
# Epoch 15/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0466 - accuracy: 0.9833 - val_loss: 0.0562 - val_accuracy: 0.9772
# Epoch 16/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0453 - accuracy: 0.9838 - val_loss: 0.0511 - val_accuracy: 0.9825
# Epoch 17/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0487 - accuracy: 0.9819 - val_loss: 0.0741 - val_accuracy: 0.9704
# Epoch 18/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0510 - accuracy: 0.9804 - val_loss: 0.0610 - val_accuracy: 0.9786
# Epoch 19/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0587 - accuracy: 0.9791 - val_loss: 0.0638 - val_accuracy: 0.9743
# Epoch 20/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0548 - accuracy: 0.9798 - val_loss: 0.0523 - val_accuracy: 0.9816
# Epoch 21/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0581 - accuracy: 0.9770 - val_loss: 0.0564 - val_accuracy: 0.9767
# Epoch 22/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0424 - accuracy: 0.9848 - val_loss: 0.0829 - val_accuracy: 0.9675
# Epoch 23/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0390 - accuracy: 0.9849 - val_loss: 0.0517 - val_accuracy: 0.9835
# Epoch 24/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0449 - accuracy: 0.9835 - val_loss: 0.0680 - val_accuracy: 0.9743
# Epoch 25/100
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0379 - accuracy: 0.9864 - val_loss: 0.0482 - val_accuracy: 0.9816
# Epoch 26/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0330 - accuracy: 0.9875 - val_loss: 0.0511 - val_accuracy: 0.9791
# Epoch 27/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0358 - accuracy: 0.9872 - val_loss: 0.0498 - val_accuracy: 0.9845
# Epoch 28/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0422 - accuracy: 0.9835 - val_loss: 0.0491 - val_accuracy: 0.9835
# Epoch 29/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0389 - accuracy: 0.9837 - val_loss: 0.0603 - val_accuracy: 0.9752
# Epoch 30/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0316 - accuracy: 0.9875 - val_loss: 0.0463 - val_accuracy: 0.9845
# Epoch 31/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0348 - accuracy: 0.9859 - val_loss: 0.0480 - val_accuracy: 0.9816
# Epoch 32/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0366 - accuracy: 0.9861 - val_loss: 0.0480 - val_accuracy: 0.9801
# Epoch 33/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0398 - accuracy: 0.9838 - val_loss: 0.0623 - val_accuracy: 0.9752
# Epoch 34/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0368 - accuracy: 0.9861 - val_loss: 0.0510 - val_accuracy: 0.9791
# Epoch 35/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0460 - accuracy: 0.9794 - val_loss: 0.0419 - val_accuracy: 0.9864
# Epoch 36/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0281 - accuracy: 0.9887 - val_loss: 0.0432 - val_accuracy: 0.9845
# Epoch 37/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0253 - accuracy: 0.9916 - val_loss: 0.0457 - val_accuracy: 0.9830
# Epoch 38/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0272 - accuracy: 0.9901 - val_loss: 0.0464 - val_accuracy: 0.9825
# Epoch 39/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0255 - accuracy: 0.9914 - val_loss: 0.0399 - val_accuracy: 0.9864
# Epoch 40/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0290 - accuracy: 0.9887 - val_loss: 0.0668 - val_accuracy: 0.9733
# Epoch 41/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0234 - accuracy: 0.9911 - val_loss: 0.0491 - val_accuracy: 0.9825
# Epoch 42/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0244 - accuracy: 0.9927 - val_loss: 0.0690 - val_accuracy: 0.9733
# Epoch 43/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0202 - accuracy: 0.9940 - val_loss: 0.0733 - val_accuracy: 0.9689
# Epoch 44/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0289 - accuracy: 0.9890 - val_loss: 0.0464 - val_accuracy: 0.9840
# Epoch 45/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0360 - accuracy: 0.9851 - val_loss: 0.0392 - val_accuracy: 0.9854
# Epoch 46/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0231 - accuracy: 0.9911 - val_loss: 0.0466 - val_accuracy: 0.9816
# Epoch 47/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0257 - accuracy: 0.9890 - val_loss: 0.0491 - val_accuracy: 0.9825
# Epoch 48/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0288 - accuracy: 0.9875 - val_loss: 0.0447 - val_accuracy: 0.9845
# Epoch 49/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0160 - accuracy: 0.9951 - val_loss: 0.0378 - val_accuracy: 0.9864
# Epoch 50/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0164 - accuracy: 0.9937 - val_loss: 0.0419 - val_accuracy: 0.9845
# Epoch 51/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0253 - accuracy: 0.9909 - val_loss: 0.0515 - val_accuracy: 0.9796
# Epoch 52/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0211 - accuracy: 0.9929 - val_loss: 0.0372 - val_accuracy: 0.9850
# Epoch 53/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0123 - accuracy: 0.9971 - val_loss: 0.0366 - val_accuracy: 0.9859
# Epoch 54/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0123 - accuracy: 0.9968 - val_loss: 0.0348 - val_accuracy: 0.9874
# Epoch 55/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.0359 - val_accuracy: 0.9869
# Epoch 56/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0210 - accuracy: 0.9921 - val_loss: 0.0482 - val_accuracy: 0.9777
# Epoch 57/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0131 - accuracy: 0.9960 - val_loss: 0.0389 - val_accuracy: 0.9874
# Epoch 58/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0115 - accuracy: 0.9969 - val_loss: 0.0357 - val_accuracy: 0.9874
# Epoch 59/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.0338 - val_accuracy: 0.9893
# Epoch 60/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0099 - accuracy: 0.9977 - val_loss: 0.0389 - val_accuracy: 0.9874
# Epoch 61/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 0.0332 - val_accuracy: 0.9888
# Epoch 62/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.0391 - val_accuracy: 0.9854
# Epoch 63/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0085 - accuracy: 0.9985 - val_loss: 0.0369 - val_accuracy: 0.9883
# Epoch 64/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0107 - accuracy: 0.9968 - val_loss: 0.0468 - val_accuracy: 0.9845
# Epoch 65/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0084 - accuracy: 0.9984 - val_loss: 0.0350 - val_accuracy: 0.9879
# Epoch 66/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0161 - accuracy: 0.9939 - val_loss: 0.0344 - val_accuracy: 0.9888
# Epoch 67/100
# 49/49 [==============================] - 0s 9ms/step - loss: 0.0146 - accuracy: 0.9947 - val_loss: 0.0755 - val_accuracy: 0.9762
# Epoch 68/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0202 - accuracy: 0.9911 - val_loss: 0.0333 - val_accuracy: 0.9888
# Epoch 69/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0135 - accuracy: 0.9943 - val_loss: 0.0309 - val_accuracy: 0.9888
# Epoch 70/100
# 49/49 [==============================] - 0s 10ms/step - loss: 0.0436 - accuracy: 0.9849 - val_loss: 0.0459 - val_accuracy: 0.9820
# Epoch 71/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0239 - accuracy: 0.9917 - val_loss: 0.0728 - val_accuracy: 0.9748
# Epoch 72/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.0796 - val_accuracy: 0.9718
# Epoch 73/100
# 49/49 [==============================] - 1s 10ms/step - loss: 0.0242 - accuracy: 0.9924 - val_loss: 0.0372 - val_accuracy: 0.9874
# Epoch 74/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0058 - accuracy: 0.9992 - val_loss: 0.0326 - val_accuracy: 0.9874
# Epoch 75/100
# 49/49 [==============================] - 1s 14ms/step - loss: 0.0045 - accuracy: 0.9995 - val_loss: 0.0318 - val_accuracy: 0.9879
# Epoch 76/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0047 - accuracy: 0.9990 - val_loss: 0.0381 - val_accuracy: 0.9869
# Epoch 77/100
# 49/49 [==============================] - 1s 11ms/step - loss: 0.0101 - accuracy: 0.9961 - val_loss: 0.0423 - val_accuracy: 0.9806
# Epoch 78/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0330 - val_accuracy: 0.9893
# Epoch 79/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0047 - accuracy: 0.9987 - val_loss: 0.0350 - val_accuracy: 0.9874
# Epoch 80/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.0321 - val_accuracy: 0.9883
# Epoch 81/100
# 49/49 [==============================] - 1s 26ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.0667 - val_accuracy: 0.9738
# Epoch 82/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0172 - accuracy: 0.9930 - val_loss: 0.0368 - val_accuracy: 0.9883
# Epoch 83/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0101 - accuracy: 0.9956 - val_loss: 0.0387 - val_accuracy: 0.9859
# Epoch 84/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0331 - val_accuracy: 0.9869
# Epoch 85/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0380 - val_accuracy: 0.9883
# Epoch 86/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0380 - val_accuracy: 0.9869
# Epoch 87/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.0356 - val_accuracy: 0.9879
# Epoch 88/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0317 - val_accuracy: 0.9874
# Epoch 89/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0356 - val_accuracy: 0.9879
# Epoch 90/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0030 - accuracy: 0.9995 - val_loss: 0.0328 - val_accuracy: 0.9879
# Epoch 91/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.0358 - val_accuracy: 0.9883
# Epoch 92/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.0302 - val_accuracy: 0.9908
# Epoch 93/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0336 - val_accuracy: 0.9879
# Epoch 94/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0373 - val_accuracy: 0.9869
# Epoch 95/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0355 - val_accuracy: 0.9883
# Epoch 96/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0569 - val_accuracy: 0.9845
# Epoch 97/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0028 - accuracy: 0.9995 - val_loss: 0.0354 - val_accuracy: 0.9883
# Epoch 98/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0638 - val_accuracy: 0.9811
# Epoch 99/100
# 49/49 [==============================] - 1s 12ms/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.0327 - val_accuracy: 0.9883
# Epoch 100/100
# 49/49 [==============================] - 1s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0333 - val_accuracy: 0.9883
# 65/65 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9854
# Epoch 1/100
# 49/49 [==============================] - 5s 32ms/step - loss: 0.6268 - accuracy: 0.7707 - val_loss: 0.2742 - val_accuracy: 0.9121
# Epoch 2/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.2129 - accuracy: 0.9267 - val_loss: 0.2201 - val_accuracy: 0.9068
# Epoch 3/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.1548 - accuracy: 0.9443 - val_loss: 0.1352 - val_accuracy: 0.9534
# Epoch 4/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1299 - accuracy: 0.9503 - val_loss: 0.1148 - val_accuracy: 0.9558
# Epoch 5/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.1001 - accuracy: 0.9641 - val_loss: 0.1449 - val_accuracy: 0.9398
# Epoch 6/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0892 - accuracy: 0.9668 - val_loss: 0.0787 - val_accuracy: 0.9733
# Epoch 7/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0706 - accuracy: 0.9770 - val_loss: 0.0734 - val_accuracy: 0.9752
# Epoch 8/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0700 - accuracy: 0.9759 - val_loss: 0.0693 - val_accuracy: 0.9757
# Epoch 9/100
# 49/49 [==============================] - 1s 22ms/step - loss: 0.0673 - accuracy: 0.9744 - val_loss: 0.0767 - val_accuracy: 0.9743
# Epoch 10/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0698 - accuracy: 0.9752 - val_loss: 0.0607 - val_accuracy: 0.9791
# Epoch 11/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0543 - accuracy: 0.9798 - val_loss: 0.0626 - val_accuracy: 0.9743
# Epoch 12/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0591 - accuracy: 0.9793 - val_loss: 0.0633 - val_accuracy: 0.9772
# Epoch 13/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0527 - accuracy: 0.9809 - val_loss: 0.0560 - val_accuracy: 0.9796
# Epoch 14/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0519 - accuracy: 0.9812 - val_loss: 0.0561 - val_accuracy: 0.9786
# Epoch 15/100
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0455 - accuracy: 0.9835 - val_loss: 0.0653 - val_accuracy: 0.9752
# Epoch 16/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0531 - accuracy: 0.9825 - val_loss: 0.1439 - val_accuracy: 0.9354
# Epoch 17/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0496 - accuracy: 0.9807 - val_loss: 0.0553 - val_accuracy: 0.9801
# Epoch 18/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0499 - accuracy: 0.9820 - val_loss: 0.0488 - val_accuracy: 0.9820
# Epoch 19/100
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0409 - accuracy: 0.9845 - val_loss: 0.0496 - val_accuracy: 0.9816
# Epoch 20/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0400 - accuracy: 0.9825 - val_loss: 0.0489 - val_accuracy: 0.9801
# Epoch 21/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0419 - accuracy: 0.9835 - val_loss: 0.0935 - val_accuracy: 0.9621
# Epoch 22/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0405 - accuracy: 0.9858 - val_loss: 0.0951 - val_accuracy: 0.9612
# Epoch 23/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0574 - accuracy: 0.9756 - val_loss: 0.0543 - val_accuracy: 0.9786
# Epoch 24/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0374 - accuracy: 0.9853 - val_loss: 0.0535 - val_accuracy: 0.9806
# Epoch 25/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0369 - accuracy: 0.9867 - val_loss: 0.0456 - val_accuracy: 0.9825
# Epoch 26/100
# 49/49 [==============================] - 1s 19ms/step - loss: 0.0323 - accuracy: 0.9892 - val_loss: 0.0535 - val_accuracy: 0.9796
# Epoch 27/100
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0417 - accuracy: 0.9832 - val_loss: 0.0607 - val_accuracy: 0.9757
# Epoch 28/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0369 - accuracy: 0.9858 - val_loss: 0.0483 - val_accuracy: 0.9825
# Epoch 29/100
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0315 - accuracy: 0.9888 - val_loss: 0.0452 - val_accuracy: 0.9835
# Epoch 30/100
# 49/49 [==============================] - 1s 24ms/step - loss: 0.0257 - accuracy: 0.9916 - val_loss: 0.0433 - val_accuracy: 0.9835
# Epoch 31/100
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0306 - accuracy: 0.9880 - val_loss: 0.0582 - val_accuracy: 0.9762
# Epoch 32/100
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0305 - accuracy: 0.9890 - val_loss: 0.0415 - val_accuracy: 0.9845
# Epoch 33/100
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0261 - accuracy: 0.9917 - val_loss: 0.0482 - val_accuracy: 0.9820
# Epoch 34/100
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0425 - val_accuracy: 0.9835
# Epoch 35/100
# 49/49 [==============================] - 1s 20ms/step - loss: 0.0254 - accuracy: 0.9919 - val_loss: 0.0431 - val_accuracy: 0.9835
# Epoch 36/100
# 49/49 [==============================] - 1s 22ms/step - loss: 0.0243 - accuracy: 0.9911 - val_loss: 0.0398 - val_accuracy: 0.9854
# Epoch 37/100
# 49/49 [==============================] - 1s 22ms/step - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.0452 - val_accuracy: 0.9835
# Epoch 38/100
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0199 - accuracy: 0.9930 - val_loss: 0.0447 - val_accuracy: 0.9835
# Epoch 39/100
# 49/49 [==============================] - 1s 21ms/step - loss: 0.0265 - accuracy: 0.9883 - val_loss: 0.0459 - val_accuracy: 0.9845
# Epoch 40/100
# 49/49 [==============================] - 1s 25ms/step - loss: 0.0191 - accuracy: 0.9937 - val_loss: 0.0418 - val_accuracy: 0.9850
# Epoch 41/100
# 49/49 [==============================] - 1s 23ms/step - loss: 0.0249 - accuracy: 0.9908 - val_loss: 0.0489 - val_accuracy: 0.9835
# Epoch 42/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.0422 - val_accuracy: 0.9859
# Epoch 43/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0177 - accuracy: 0.9947 - val_loss: 0.0427 - val_accuracy: 0.9840
# Epoch 44/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0202 - accuracy: 0.9932 - val_loss: 0.0422 - val_accuracy: 0.9840
# Epoch 45/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0244 - accuracy: 0.9914 - val_loss: 0.0397 - val_accuracy: 0.9864
# Epoch 46/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0405 - val_accuracy: 0.9840
# Epoch 47/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0142 - accuracy: 0.9966 - val_loss: 0.0385 - val_accuracy: 0.9854
# Epoch 48/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.0374 - val_accuracy: 0.9879
# Epoch 49/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0450 - val_accuracy: 0.9830
# Epoch 50/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.0444 - val_accuracy: 0.9830
# Epoch 51/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0129 - accuracy: 0.9963 - val_loss: 0.0451 - val_accuracy: 0.9835
# Epoch 52/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0277 - accuracy: 0.9905 - val_loss: 0.0359 - val_accuracy: 0.9879
# Epoch 53/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0127 - accuracy: 0.9960 - val_loss: 0.0446 - val_accuracy: 0.9820
# Epoch 54/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.0365 - val_accuracy: 0.9869
# Epoch 55/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0167 - accuracy: 0.9934 - val_loss: 0.0452 - val_accuracy: 0.9850
# Epoch 56/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.0344 - val_accuracy: 0.9888
# Epoch 57/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.0468 - val_accuracy: 0.9820
# Epoch 58/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0193 - accuracy: 0.9924 - val_loss: 0.0364 - val_accuracy: 0.9864
# Epoch 59/100
# 49/49 [==============================] - 1s 17ms/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.0347 - val_accuracy: 0.9883
# Epoch 60/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0099 - accuracy: 0.9972 - val_loss: 0.0346 - val_accuracy: 0.9864
# Epoch 61/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0079 - accuracy: 0.9985 - val_loss: 0.0327 - val_accuracy: 0.9888
# Epoch 62/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0085 - accuracy: 0.9977 - val_loss: 0.0343 - val_accuracy: 0.9879
# Epoch 63/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.0336 - val_accuracy: 0.9883
# Epoch 64/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0512 - val_accuracy: 0.9816
# Epoch 65/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0444 - val_accuracy: 0.9835
# Epoch 66/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0153 - accuracy: 0.9940 - val_loss: 0.0377 - val_accuracy: 0.9883
# Epoch 67/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0253 - accuracy: 0.9893 - val_loss: 0.0455 - val_accuracy: 0.9786
# Epoch 68/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0104 - accuracy: 0.9968 - val_loss: 0.0353 - val_accuracy: 0.9883
# Epoch 69/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0135 - accuracy: 0.9951 - val_loss: 0.0334 - val_accuracy: 0.9864
# Epoch 70/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0079 - accuracy: 0.9984 - val_loss: 0.0358 - val_accuracy: 0.9879
# Epoch 71/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.0356 - val_accuracy: 0.9874
# Epoch 72/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.0402 - val_accuracy: 0.9850
# Epoch 73/100
# 49/49 [==============================] - 1s 18ms/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.0357 - val_accuracy: 0.9864
# Epoch 74/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.0345 - val_accuracy: 0.9874
# Epoch 75/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0041 - accuracy: 0.9992 - val_loss: 0.0356 - val_accuracy: 0.9883
# Epoch 76/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0380 - val_accuracy: 0.9869
# Epoch 77/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0329 - val_accuracy: 0.9883
# Epoch 78/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 0.0340 - val_accuracy: 0.9883
# Epoch 79/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0041 - accuracy: 0.9989 - val_loss: 0.0381 - val_accuracy: 0.9859
# Epoch 80/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0071 - accuracy: 0.9982 - val_loss: 0.0310 - val_accuracy: 0.9888
# Epoch 81/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.0318 - val_accuracy: 0.9879
# Epoch 82/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.0311 - val_accuracy: 0.9888
# Epoch 83/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.0320 - val_accuracy: 0.9898
# Epoch 84/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.0333 - val_accuracy: 0.9888
# Epoch 85/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0413 - val_accuracy: 0.9859
# Epoch 86/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0038 - accuracy: 0.9995 - val_loss: 0.0334 - val_accuracy: 0.9888
# Epoch 87/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0333 - val_accuracy: 0.9883
# Epoch 88/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0320 - val_accuracy: 0.9898
# Epoch 89/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0333 - val_accuracy: 0.9893
# Epoch 90/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9879
# Epoch 91/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.0343 - val_accuracy: 0.9883
# Epoch 92/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0416 - val_accuracy: 0.9874
# Epoch 93/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0036 - accuracy: 0.9992 - val_loss: 0.1954 - val_accuracy: 0.9500
# Epoch 94/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0969 - accuracy: 0.9746 - val_loss: 0.0413 - val_accuracy: 0.9864
# Epoch 95/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.0371 - val_accuracy: 0.9869
# Epoch 96/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0368 - val_accuracy: 0.9879
# Epoch 97/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0043 - accuracy: 0.9997 - val_loss: 0.0337 - val_accuracy: 0.9888
# Epoch 98/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.0318 - val_accuracy: 0.9893
# Epoch 99/100
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0309 - val_accuracy: 0.9903
# Epoch 100/100
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0303 - val_accuracy: 0.9903
# 65/65 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9874

# %% [markdown]
# ### IX. Tabular the results, compare them and write your findings.

# %%
res_table = {
             'Model': ['SimpleRNN', 
                       'GRU', 
                       'LSTM', 
                       'Bidirectional GRU', 
                       'Bidirectional LSTM'],
             'Loss': [simple_rnn_eval[0], 
                      gru_eval[0], 
                      lstm_eval[0], 
                      bi_gru_eval[0], 
                      bi_lstm_eval[0]],
             'Accuracy': [simple_rnn_eval[1]*100, 
                          gru_eval[1]*100, 
                          lstm_eval[1]*100, 
                          bi_gru_eval[1]*100, 
                          bi_lstm_eval[1]*100],
             'Total Parameters': [model_simple_rnn.count_params(), 
                                  model_gru.count_params(), 
                                  model_lstm.count_params(), 
                                  model_bi_gru.count_params(),
                                  model_bi_lstm.count_params()]
            }

res_table = pd.DataFrame(res_table)

print(tabulate(res_table, 
               headers=res_table.keys(), 
               tablefmt='github'))
# Out:
# |    | Model              |      Loss |   Accuracy |   Total Parameters |
# |----|--------------------|-----------|------------|--------------------|
# |  0 | SimpleRNN          | 0.044903  |    98.5437 |              89094 |
# |  1 | GRU                | 0.0435381 |    98.5922 |             266118 |
# |  2 | LSTM               | 0.0469273 |    98.3981 |             354054 |
# |  3 | Bidirectional GRU  | 0.048402  |    98.5437 |             532230 |
# |  4 | Bidirectional LSTM | 0.0450078 |    98.7379 |             708102 |

# %% [markdown]
# Despite the considerable difference in the models’ total parameters, there is no significant difference between accuracies and losses. So, the preferable model would be the simplest one with the least trainable parameters, which is the Simple_RNN model.

# %%
model_simple_rnn.summary()
model_gru.summary()
model_lstm.summary()
model_bi_gru.summary()
model_bi_lstm.summary()
# Out:
# Model: "Simple_RNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden_Layer (SimpleRNN)    (None, 128)               88320
#
#  Output_Layer (Dense)        (None, 6)                 774
#
# =================================================================
# Total params: 89,094
# Trainable params: 89,094
# Non-trainable params: 0
# _________________________________________________________________
# Model: "GRU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Hidden_Layer (GRU)          (None, 128)               265344
#
#  Output_Layer (Dense)        (None, 6)                 774
#
# =================================================================
# Total params: 266,118
# Trainable params: 266,118
# Non-trainable params: 0
# _________________________________________________________________
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (LSTM)          (None, 128)               353280
#
#  Output_Layer (Dense)        (None, 6)                 774
#
# =================================================================
# Total params: 354,054
# Trainable params: 354,054
# Non-trainable params: 0
# _________________________________________________________________
# Model: "Bi_GRU"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (Bidirectional)  (None, 256)              530688
#
#  Output_Layer (Dense)        (None, 6)                 1542
#
# =================================================================
# Total params: 532,230
# Trainable params: 532,230
# Non-trainable params: 0
# _________________________________________________________________
# Model: "Bi_LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input_Layer (Bidirectional)  (None, 256)              706560
#
#  Output_Layer (Dense)        (None, 6)                 1542
#
# =================================================================
# Total params: 708,102
# Trainable params: 708,102
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### X. Bonus: There's an intriguing paper that presents the Forward-Forward algorithm. This algorithm replaces the forward and backward passes of backpropagation with two forward passes. The first pass involves positive (i.e., real) data, while the second pass involves negative data that can be generated by the network itself. Explore the intriguing aspects of this algorithm by delving into the paper. (bearing in mind that it was published in 2022, after Chatgpt knowledge cutoff date of 2021).

# %% [markdown]
# Backpropagation is an algorithm used to train deep learning models by iteratively adjusting the neuron weights to make the network's output closer to the desired output.
# The backpropagation algorithm starts by inputting data into the network and passing it through the layers. The weights of the neurons in each layer transform the input data, generating an output. This output is then compared to the desired output, and the algorithm calculates the error between them. The error is then propagated backward through the network, starting from the output layer and moving through the hidden layers.
# During the backward propagation, the neuron weights are adjusted to minimize the error. This process is repeated for multiple iterations until the error reaches an acceptable level. The backpropagation algorithm employs a mathematical technique called gradient descent to optimize the neuron weights. Gradient descent helps find the optimal weights that minimize the difference between the network's output and the desired output.
#
# Backpropagation has several significant drawbacks. It is not considered a plausible model for how the brain learns and lacks support from evidence in the visual system. It also faces challenges in handling sequences and real-time learning efficiently. Another drawback is its reliance on a perfect model of the forward computation to compute accurate derivatives. Furthermore, when used with reinforcement learning techniques, backpropagation can suffer from high variance, which hampers its efficiency, particularly for large networks with numerous parameters. These limitations have prompted the development of alternative methods like the Forward-Forward Algorithm. This alternative approach aims to address the shortcomings of backpropagation and can be employed when the exact details of the forward computation are unknown.
#
# The Forward-Forward (FF) algorithm is an alternative method for training neural networks, particularly useful in scenarios involving GANs or reinforcement learning. It operates by utilizing two forward passes: one with real (positive) data and another with negative data, which can be generated by the network itself. Each layer in the network has its own objective function, aiming for high goodness with positive data and low goodness with negative data. The FF algorithm is beneficial when the precise details of the forward computation are unknown or when real-time processing of sequential data is required without error derivative propagation. However, it currently exhibits lower efficiency and generalization compared to traditional backpropagation in certain tasks.
# In the context of a paper, positive data refers to genuine data, while negative data represents artificial or generated data. The negative data can be manually added or generated by the model itself. To clarify, let's consider an example in the context of supervised learning.
# In traditional backpropagation, a 2-layer dense neural network is typically trained for image classification. This involves feeding data through the network, comparing the output to the desired labels, calculating a loss function, computing the derivative of the loss with respect to the model's parameters, and updating the weights accordingly.
# In the FF algorithm, training a 2-layer dense neural network for image classification takes a different approach. Rather than pushing data through the network, comparing the outcome to labels, and using backpropagation to update the weights, the labels and data are combined into a single vector known as "good data." Additionally, "bad data" is generated by pairing input images with incorrect labels. An example using the MNIST dataset of handwritten digits is provided, where the first 10 pixels are replaced with a one-of-N representation of the label for simplicity.
# The training process for the FF algorithm is straightforward. It involves calculating the sum of squared activations within a layer to maximize the model's performance on "good data" while minimizing it on "bad data." Since this calculation is performed within each layer, backpropagation is unnecessary, and instead, the layer itself performs a relatively simple derivative of the function.
#
# In the context of neural networks, "neural activities" refer to the output or response of the neurons within a network. This encompasses various aspects such as the activation values of individual neurons, the output of a specific layer, or the overall output of the entire network. The term "neural activities" describes the collective behavior or output of the network and serves as a basis for evaluating and optimizing its performance.
# In the Forward-Forward algorithm, the objective is to ensure that each layer in the network exhibits positive responses (high neural activity) to good data and negative responses (low neural activity) to bad data. This helps in achieving desirable behavior throughout the network by maintaining appropriate activation levels and avoiding excessive activations caused by high inputs from preceding layers. To accomplish this, the activations of the layers are normalized by dividing them by the norm of the activation vector between layers.
# The Forward-Forward algorithm presents a novel learning approach for neural networks, replacing the traditional forward and backward passes of backpropagation with two forward passes. These passes involve positive data and negative data, which can be generated by the network itself. The fundamental concept is to train the model using both positive and negative data, aiming for high goodness with positive data and low goodness with negative data. This innovative algorithm holds promise in the field of deep learning and merits consideration for future projects, as it may unlock new opportunities.
